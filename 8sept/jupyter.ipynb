# %%
name=("mayank")
clas=("btech cse ai/ml ")
age=19
print(name)
# Out:
# mayank

# %%
data = {
    "name": "Mayank",
    "classs": "Btech cse ai/ml",
    "age": 19
}

print(data, type(data))
print(data["name"])
# Out:
# {'name': 'Mayank', 'classs': 'Btech cse ai/ml', 'age': 19} <class 'dict'>
# Mayank
